# %% [markdown]
# <a href="https://colab.research.google.com/github/girishnn/demo1/blob/main/girish.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data={
    'NAME':['RUPA','SITA','GEETA'],
    'AGE':[25,30,35],
    'CITY':['BAGALKOT','SOLAPUR','GULBARGA']
}
df=pd.DataFrame(data)
print(df)
# Out:
#     NAME  AGE      CITY
# 0   RUPA   25  BAGALKOT
# 1   SITA   30   SOLAPUR
# 2  GEETA   35  GULBARGA

# %%
import numpy as np
import random
array = np.random.randint(16,size=(4,4))
print("Input Array: \n",array)
print("largest number in x axis: ",np.max(array,axis=1))
print("largest number in y axis: ",np.max(array,axis=0))
# Out:
# Input Array:
#  [[ 0  1 15 11]
#  [ 3  6  8  6]
#  [10 15 10  7]
#  [ 4 12  8 14]]
# largest number in x axis:  [15  8 15 14]
# largest number in y axis:  [10 15 15 14]

# %%
import numpy as np
import random
array = np.random.randint(16,size=(4,4))
print("Input Array: \n",array)
print("Smallest number in x axis: ",np.min(array,axis=1))
print("Smallest number in y axis: ",np.min(array,axis=0))
# Out:
# Input Array:
#  [[14  5  5  2]
#  [ 8  0 11  1]
#  [ 6 14  4  5]
#  [ 5  8  5 12]]
# Smallest number in x axis:  [2 0 4 5]
# Smallest number in y axis:  [5 0 4 1]

# %%
def square(number):
          return number*number
nums= [1,2,3,4]
squared_numbers = list(map(square,nums))
print(squared_numbers)
nums1= [1,2,3,4,5,6]
squareOfnums1 = list(map(lambda n:n*n,nums1))
print(squareOfnums1)
# Out:
# [1, 4, 9, 16]
# [1, 4, 9, 16, 25, 36]

# %%
import numpy as np
import pandas as pd  # Missing import

exam_data = {
    'name': ['Manish', 'Dhiraj', 'Man', 'Dhir'],
    'score': [12.5, 91, 20.5, 19]
}

df = pd.DataFrame(exam_data)
df = df.rename(columns={'name': 'NAME', 'score': 'SCORE'})

print("New DataFrame after renaming columns:")
print(df)
# Out:
# New DataFrame after renaming columns:
#      NAME  SCORE
# 0  Manish   12.5
# 1  Dhiraj   91.0
# 2     Man   20.5
# 3    Dhir   19.0

# %%
def is_even(n):
    if n % 2 == 0:
        return True
    else:
        return False

nums = [1, 2, 3, 4]
evens = list(filter(is_even, nums))
print(evens)
# Out:
# [2, 4]

# %%
import pandas as pd
import numpy as np

exam_data = {
    'name': ['Manish', 'Dhiraj', 'Man', 'Dhir'],
    'score': [12.5, 91, 20.5, 19]
}

df = pd.DataFrame(exam_data)


df = df[df['score'] >= 20]

print("New DataFrame")
print(df)
# Out:
# New DataFrame
#      name  score
# 1  Dhiraj   91.0
# 2     Man   20.5

# %%
import pandas as pd
import numpy as np

s1 = pd.Series(['100', '200', '400'])
s2 = pd.Series(['10', '20', '40'])

print("Data Series:")
print(s1)
print(s2)


df = pd.concat([s1, s2], axis=1)
df.columns = ['Column1', 'Column2']

print("New DataFrame combining two series:")
print(df)
# Out:
# Data Series:
# 0    100
# 1    200
# 2    400
# dtype: object
# 0    10
# 1    20
# 2    40
# dtype: object
# New DataFrame combining two series:
#   Column1 Column2
# 0     100      10
# 1     200      20
# 2     400      40

# %%
import pandas as pd
data={
    'Name':['']

# %%
import pandas as pd
data={
    'NAME':['RUPA','SITA','GEETA'],
    'AGE':[25,30,35],
    'CITY':['BAGALKOT','SOLAPUR','GULBARGA']
}
df=pd.DataFrame(data)
df_sorted=df.sort_values(by='AGE',ascending=False)
print(df_sorted)
# Out:
#     NAME  AGE      CITY
# 2  GEETA   35  GULBARGA
# 1   SITA   30   SOLAPUR
# 0   RUPA   25  BAGALKOT

# %%
import pandas as pd
data={
    'NAME':['RUPA','SITA','GEETA'],
    'AGE':[25,30,35],
    'CITY':['BAGALKOT','SOLAPUR','GULBARGA'],
    'SALARY':[50000,60000,70000]
}
df=pd.DataFrame(data)
print(df)
# Out:
#     NAME  AGE      CITY  SALARY
# 0   RUPA   25  BAGALKOT   50000
# 1   SITA   30   SOLAPUR   60000
# 2  GEETA   35  GULBARGA   70000

# %%
import pandas as pd
data={
    'NAME':['RUPA','SITA','GEETA'],
    'AGE':[25,30,35],
    'CITY':['BAGALKOT','SOLAPUR','GULBARGA']
}

df=pd.DataFrame(data)
age=df[df['AGE']>30]
print(df)
print("\nthe age above 30:\n",age)
# Out:
#     NAME  AGE      CITY
# 0   RUPA   25  BAGALKOT
# 1   SITA   30   SOLAPUR
# 2  GEETA   35  GULBARGA
#
# the age above 30:
#      NAME  AGE      CITY
# 2  GEETA   35  GULBARGA

# %%
import pandas as pd
data={
    'NAME':['RUPA','SITA','GEETA'],
    'AGE':[25,30,35],
    'CITY':['BAGALKOT','SOLAPUR','GULBARGA'],
    'SALARY':[50000,60000,70000]
}
df=pd.DataFrame(data)
df.loc[df['NAME']=='SITA','CITY']='BAGALKOT'
print(df)
# Out:
#     NAME  AGE      CITY  SALARY
# 0   RUPA   25  BAGALKOT   50000
# 1   SITA   30  BAGALKOT   60000
# 2  GEETA   35  GULBARGA   70000

# %%
import pandas as pd
data={
    'NAME':['RUPA','SITA','GEETA'],
    'AGE':[25,30,35],
    'CITY':['BAGALKOT','SOLAPUR','GULBARGA'],
    'SALARY':[50000,60000,70000]
}
df=pd.DataFrame(data)
df=df.drop('CITY',axis=1)
print(df)
# Out:
#     NAME  AGE  SALARY
# 0   RUPA   25   50000
# 1   SITA   30   60000
# 2  GEETA   35   70000

# %%
import pandas as pd
data={
    'NAME':['RUPA','SITA','GEETA'],
    'AGE':[25,30,35],
    'SALARY':[50000,60000,70000]
}
df=pd.DataFrame(data)
df_age=df['AGE'].mean()
print(df_age)
# Out:
# 30.0

# %%
import pandas as pd
data={
    'NAME':['RUPA','SITA','GEETA'],
    'AGE':[25,30,35],
    'CITY':['BAGALKOT','SOLAPUR','GULBARGA'],
    'SALARY':[50000,60000,70000]
}
df=pd.DataFrame(data)
df_from=(df['CITY']=='BAGALKOT').any()
print(df_from)
# Out:
# True

# %%
import pandas as pd
data={
    'NAME':['RUPA','SITA','GEETA'],
    'AGE':[25,30,35],
    'CITY':['BAGALKOT','SOLAPUR','GULBARGA'],
    'SALARY':[50000,60000,70000]
}
df=pd.DataFrame(data)
sita_info=df[df['NAME']=='SITA']
print(sita_info)
# Out:
#    NAME  AGE     CITY  SALARY
# 1  SITA   30  SOLAPUR   60000

# %%
import pandas as pd
data={
    'NAME':['RUPA','SITA','GEETA'],
    'AGE':[25,30,35],
    'CITY':['BAGALKOT','SOLAPUR','GULBARGA'],
    'SALARY':[50000,60000,70000]
}
df=pd.DataFrame(data)
city_counts=df['CITY'].value_counts()
print(city_counts)
# Out:
# CITY
# BAGALKOT    1
# SOLAPUR     1
# GULBARGA    1
# Name: count, dtype: int64

# %%
import pandas as pd
data={
    'NAME':['RUPA','SITA','GEETA'],
    'AGE':[25,30,35],
    'CITY':['BAGALKOT','SOLAPUR','GULBARGA'],
    'SALARY':[50000,60000,70000]
}
df=pd.DataFrame(data)
df_salary=df[df['SALARY']==df['SALARY'].max()]
print(df_salary)
# Out:
#     NAME  AGE      CITY  SALARY
# 2  GEETA   35  GULBARGA   70000

# %%
import matplotlib.pyplot as plt
categories = ['Category A', 'Category B', 'Category C']
amounts = [25, 50, 30]
plt.bar(categories, amounts)
plt.xlabel('Categories')
plt.ylabel('Amounts')
plt.title('Bar Chart of Amounts by Category')
plt.show()

# %%
import matplotlib.pyplot as plt
categories = ['Category A', 'Category B', 'Category C']
amounts = [25, 50, 30]
plt.pie(amounts, labels=categories, autopct='%1.1f%%')
plt.title('Pie Chart of Amounts by Category')
plt.show()

# %%
import matplotlib.pyplot as plt
years = [2010, 2011, 2012, 2013, 2014]
amounts = [100, 120, 140, 110, 150]
plt.plot(years, amounts, marker='o', linestyle='-')
plt.xlabel('Year')
plt.ylabel('Amount')
plt.title('Line Chart of Amounts Over Time')
plt.grid(True) # Add a grid for better readability
plt.show()

# %%
import matplotlib.pyplot as plt
x = [10, 20, 30, 40, 50]
y = [50, 40, 30, 20, 10]
plt.scatter(x, y)
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.title('Scatter Plot of X vs. Y')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
data = np.random.randn(1000)
plt.hist(data, bins=20, edgecolor='k')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram of Data')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
mu, sigma = 0, 1
data = np.random.normal(mu, sigma, 1000)
plt.hist(data, bins=30, edgecolor='k', alpha=0.7)
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram of a Normal Distribution')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
low, high = 0, 10
data = np.random.uniform(low, high, 1000)
plt.hist(data, bins=20, edgecolor='k', alpha=0.7)
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram of a Uniform Distribution')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
scale = 1.0
data = np.random.exponential(scale, 1000)
plt.hist(data, bins=20, edgecolor='k', alpha=0.7)
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram of an Exponential Distribution')
plt.grid(True)
plt.show()

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
mu, sigma = 0, 1
data = np.random.normal(mu, sigma, 1000)
sns.kdeplot(data, shade=True)
plt.xlabel('Value')
plt.ylabel('Density')
plt.title('Kernel Density Estimation (KDE) Plot of a Normal Distribution')
plt.show()
# Out:
# /tmp/ipython-input-13-2960664892.py:6: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data, shade=True)
